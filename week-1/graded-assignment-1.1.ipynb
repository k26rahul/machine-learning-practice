# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("data/Week1_GA_dataset.csv")
df.sample(5)
df.shape
# Out:
#             Date  Year       Locality  Estimated Value  Sale Price  \
# 359   2009-06-07  2009     Bridgeport          95130.0    184000.0
# 9311  2022-02-10  2022       Stamford         967530.0   1050000.0
# 5079  2016-10-28  2016      Greenwich         396200.0    750000.0
# 5973  2017-10-13  2017  West Hartford         193970.0    296125.0
# 1062  2010-07-24  2010        Norwalk         290220.0    467000.0
#
#            Property     Residential  num_rooms  num_bathrooms  carpet_area  \
# 359      Two Family          Duplex          4              4       1307.0
# 9311              ?  Detached House          3              2       1043.0
# 5079  Single Family  Detached House          3              2        944.0
# 5973              ?  Detached House          3              1        923.0
# 1062  Single Family  Detached House          3              1       1007.0
#
#       property_tax_rate   Face
# 359            1.025953  South
# 9311           1.003979  North
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               10000 non-null  str
#  1   Year               10000 non-null  int64
#  2   Locality           8747 non-null   str
#  3   Estimated Value    8757 non-null   float64
#  4   Sale Price         10000 non-null  float64
#  5   Property           10000 non-null  str
#  6   Residential        10000 non-null  str
#  7   num_rooms          10000 non-null  int64
#  8   num_bathrooms      10000 non-null  int64
#  9   carpet_area        8771 non-null   float64
#  10  property_tax_rate  10000 non-null  float64
#  11  Face               10000 non-null  str
# dtypes: float64(4), int64(3), str(5)
# memory usage: 937.6 KB

# %%
# (df == '?')  # bool mask
# (df == '?').sum()  # col-wise totals
(df == '?').sum().sum()  # net total across all cols
# Out:
# np.int64(1823)

# %%
df[df == '?'] = pd.NA
(df == '?').sum().sum()  # no more "?"
# Out:
# np.int64(0)

# %%
df.iloc[692, 0]
df.iloc[546, 7]
# Out:
# '2009-11-16'
# np.int64(3)

# %%
df['Locality'].value_counts().shape
# Out:
# (7,)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               10000 non-null  str
#  1   Year               10000 non-null  int64
#  2   Locality           8747 non-null   str
#  3   Estimated Value    8757 non-null   float64
#  4   Sale Price         10000 non-null  float64
#  5   Property           8177 non-null   str
#  6   Residential        10000 non-null  str
#  7   num_rooms          10000 non-null  int64
#  8   num_bathrooms      10000 non-null  int64
#  9   carpet_area        8771 non-null   float64
#  10  property_tax_rate  10000 non-null  float64
#  11  Face               10000 non-null  str
# dtypes: float64(4), int64(3), str(5)
# memory usage: 937.6 KB

# %%
mask = df.isnull().sum(axis=1) > 2
indices_to_drop = df[mask].index
df.drop(indices_to_drop, axis=0)
# Out:
#             Date  Year    Locality  Estimated Value  Sale Price  \
# 0     2009-01-02  2009   Waterbury         111440.0    185000.0
# 1     2009-01-02  2009  Bridgeport         124670.0    150000.0
# 2     2009-01-02  2009   Waterbury          55720.0    140000.0
# 3     2009-01-02  2009  Bridgeport        4775276.0    272900.0
# 4     2009-01-02  2009  Bridgeport         112351.0    210000.0
# ...          ...   ...         ...              ...         ...
# 9995  2022-09-30  2022  Bridgeport         153660.0    322000.0
# 9996  2022-09-30  2022  Bridgeport         109820.0    340000.0
# 9997  2022-09-30  2022   Waterbury          83210.0    170000.0
# 9998  2022-09-30  2022         NaN         216420.0    415000.0
# 9999  2022-09-30  2022     Norwalk         154920.0    196000.0
#
#            Property     Residential  num_rooms  num_bathrooms  carpet_area  \
# 0     Single Family  Detached House          3              3        996.0
# ...

# %%
df.dropna()
# Out:
#             Date  Year       Locality  Estimated Value  Sale Price  \
# 0     2009-01-02  2009      Waterbury         111440.0    185000.0
# 1     2009-01-02  2009     Bridgeport         124670.0    150000.0
# 2     2009-01-02  2009      Waterbury          55720.0    140000.0
# 3     2009-01-02  2009     Bridgeport        4775276.0    272900.0
# 5     2009-01-02  2009      Greenwich        2868880.0   3300000.0
# ...          ...   ...            ...              ...         ...
# 9986  2022-09-28  2022        Norwalk         305820.0    535000.0
# 9987  2022-09-28  2022        Norwalk         450510.0    677000.0
# 9993  2022-09-30  2022  West Hartford         121870.0    235000.0
# 9997  2022-09-30  2022      Waterbury          83210.0    170000.0
# 9999  2022-09-30  2022        Norwalk         154920.0    196000.0
#
#            Property     Residential  num_rooms  num_bathrooms  carpet_area  \
# 0     Single Family  Detached House          3              3        996.0
# ...
