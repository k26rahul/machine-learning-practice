# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("data/Week1_GA_dataset.csv")
df.sample(5)
df.shape
# Out:
#             Date  Year       Locality  Estimated Value  Sale Price  \
# 6169  2018-02-17  2018  West Hartford              NaN    340000.0
# 1906  2012-02-22  2012       Stamford         509030.0    625000.0
# 5056  2016-10-20  2016      Fairfield         362320.0    490000.0
# 3448  2014-07-02  2014     Bridgeport         132250.0     84900.0
# 8033  2020-09-04  2020     Bridgeport         118290.0    141200.0
#
#            Property     Residential  num_rooms  num_bathrooms  carpet_area  \
# 6169  Single Family  Detached House          3              1       1054.0
# 1906  Single Family  Detached House          3              2        957.0
# 5056  Single Family  Detached House          3              3       1063.0
# 3448  Single Family  Detached House          3              3       1039.0
# 8033  Single Family  Detached House          3              2        971.0
#
#       property_tax_rate   Face
# 6169           1.422308  North
# 1906           1.021958   West
# 5056           1.348259   East
# 3448           1.350819   West
# 8033           1.025440   East
# (10000, 12)

# %%
df.iloc[::2].iloc[0, 3]
df.iloc[::2].iloc[332, 3]
# Out:
# np.float64(111440.0)
# np.float64(256200.0)

# %%
df.iloc[1::2].iloc[332, 3]
df.iloc[1::2].iloc[100, 5]
# Out:
# np.float64(352940.0)
# 'Single Family'

# %%
df.iloc[::2, ::2].iloc[255, 3]
# Out:
# 'Detached House'

# %%
last_six_years = df['Year'].value_counts().sort_index(ascending=False)[:6]
last_six_years
last_six_years.sum()
# Out:
# Year
# 2022    789
# 2021    929
# 2020    724
# 2019    800
# 2018    641
# 2017    866
# Name: count, dtype: int64
# np.int64(4749)

# %%
((df['num_rooms'] == 3) & (df['num_bathrooms'] == 3)).sum()
((df['num_rooms'] == 3) | (df['num_bathrooms'] == 3)).sum()
# Out:
# np.int64(2730)
# np.int64(8591)

# %%
mask = (df['Year'] == 2022) \
    & (df['Locality'] == 'Greenwich') \
    & (df['num_rooms'] == 3) \
    & (df['Face'].isin(['North', 'East']))

mask.sum()
# Out:
# np.int64(42)

# %%
(df['Date'].str[5:7] == '08').sum()
# Out:
# np.int64(1050)

# %%
grp = df.groupby('Locality')
sales = grp['Sale Price'].mean()
sales.index[sales.argmax()]
# Out:
# 'Greenwich'

# %%
series = pd.Series(
    data=[50, 90, 70, 55],
    index=['rahul', 'vidu', 'paru', 'vishnu']
)

series.index[series.argmax()]
# Out:
# 'vidu'
